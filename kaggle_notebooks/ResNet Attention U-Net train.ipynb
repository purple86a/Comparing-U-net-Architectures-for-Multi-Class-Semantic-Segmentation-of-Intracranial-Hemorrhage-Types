# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5f53ab26_ID_f1c7d54a53_slice_018_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ba3a77dd_ID_70715be365_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56983eda_ID_a1eb0918d6_slice_013_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_790acb3f_ID_c294f81468_slice_016_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a84354a5_ID_6699da85bb_slice_014_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_09b33fc4_ID_bcd322d4ed_slice_011_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7d5594ff_ID_cb535d3e8b_slice_010_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_cb4c887c_ID_ec2a4643f3_slice_021_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e05b3047_ID_3d78428b2d_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_007_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_042_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e1d9fe9d_ID_f73aea5186_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_027_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_199b0a56_ID_09e623e993_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_96cd5341_ID_41b80bd3ec_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_46cd34ad_ID_3003623499_slice_023_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_338738e7_ID_0808281b2a_slice_008_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_96cd5341_ID_41b80bd3ec_slice_010_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_85f42dd5_ID_a0ef1a9eaf_slice_027_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7d5594ff_ID_cb535d3e8b_slice_021_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_346de481_ID_2e8fea0d9a_slice_006_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_596dfbc1_ID_fe7dab2602_slice_016_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3dab46e7_ID_e837f87e46_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7db5845a_ID_0c7cd6982b_slice_013_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_036_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ca7bbeab_ID_228e9cbe5c_slice_011_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_daf22e49_ID_bf76e84f8d_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ec8a7bf0_ID_c853ba89ce_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_495ac92a_ID_4daa7b9cc7_slice_012_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d29d246b_ID_6121b401e7_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_811a274b_ID_fa1c9402fb_slice_019_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_029ebbea_ID_563afa0901_slice_022_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0492041f_ID_b4fcf2f799_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ba3a77dd_ID_70715be365_slice_013_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0492041f_ID_b4fcf2f799_slice_009_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b80aec97_ID_2aa91505e6_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b367130b_ID_debc60a9ba_slice_022_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b85bdbe9_ID_cb52cd5d53_slice_018_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_751df220_ID_4c26128a8d_slice_000_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5117f9bf_ID_14d96feecf_slice_014_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b85bdbe9_ID_cb52cd5d53_slice_010_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_693f2d48_ID_06a88c0e8b_slice_009_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_811a274b_ID_fa1c9402fb_slice_019_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_596dfbc1_ID_fe7dab2602_slice_022_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_75448f16_ID_780b14c9d7_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_008_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39e94772_ID_f1a5ef6a24_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_017_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f335b6db_ID_d180629430_slice_018_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4a16396b_ID_1f3e0c2c5c_slice_018_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f4795940_ID_6317a06429_slice_009_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_014_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_495ac92a_ID_4daa7b9cc7_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ea687366_ID_452c5f1f8c_slice_029_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c08a7b51_ID_b98f437f69_slice_025_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5f53ab26_ID_f1c7d54a53_slice_007_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ccbe16e6_ID_706deb5ba2_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_8e8df8c0_ID_857231e0c6_slice_015_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39e94772_ID_f1a5ef6a24_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_18747540_ID_1eb1de9633_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39e94772_ID_f1a5ef6a24_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_552aabb9_ID_152fdcf86e_slice_011_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ccbe16e6_ID_706deb5ba2_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_012_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_1879071b_ID_4b8e1377e7_slice_027_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_751df220_ID_4c26128a8d_slice_000_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_50b54af0_ID_fbeeed4370_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7860208e_ID_f68c193b69_slice_013_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_fcbe7eda_ID_5726e1c630_slice_007_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_75448f16_ID_780b14c9d7_slice_007_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_196704db_ID_4eb6296376_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_024_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_96cd5341_ID_41b80bd3ec_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e714812a_ID_11a3b1afdc_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df935041_ID_32b8592d2c_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ab1ba874_ID_0c1c9bf0ae_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_80b8d734_ID_f599f2d14b_slice_023_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_8e8df8c0_ID_857231e0c6_slice_019_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3dab46e7_ID_e837f87e46_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a84354a5_ID_6699da85bb_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d8e67d7d_ID_c182bd8176_slice_021_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ca7bbeab_ID_228e9cbe5c_slice_024_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56983eda_ID_a1eb0918d6_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_cdaa21cb_ID_a5f7ae30f1_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_90233c1a_ID_51c49c9abf_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2db7ee14_ID_f27e38fdfd_slice_012_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_cdaa21cb_ID_a5f7ae30f1_slice_014_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c3769f3a_ID_32fc557515_slice_016_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a2ddcdfe_ID_d7aedfd21f_slice_025_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9dce269b_ID_4191982e02_slice_027_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3be7cc35_ID_cf2643c5a8_slice_009_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_8e8df8c0_ID_857231e0c6_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c91d516c_ID_2d2f3d2953_slice_010_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_88dbe13f_ID_01c5078fbf_slice_018_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a84354a5_ID_6699da85bb_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56983eda_ID_a1eb0918d6_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_75448f16_ID_780b14c9d7_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_552aabb9_ID_152fdcf86e_slice_011_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ca7bbeab_ID_228e9cbe5c_slice_010_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2872834a_ID_542e9d00da_slice_006_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_83a07ec6_ID_ef148a90ed_slice_024_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e3db11e0_ID_1863688c5b_slice_019_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e566ef9b_ID_439ce9720b_slice_025_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_66a9a60e_ID_3a4f389a07_slice_032_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_94271e7f_ID_50fb725eb8_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_790acb3f_ID_c294f81468_slice_010_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c488fbef_ID_ae4af6dd21_slice_019_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a554892c_ID_7d5bccea0e_slice_015_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e566ef9b_ID_439ce9720b_slice_026_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4e25e744_ID_b0275c19cd_slice_023_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b85bdbe9_ID_cb52cd5d53_slice_020_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e2e2e522_ID_7b7b5543dc_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a2ddcdfe_ID_d7aedfd21f_slice_017_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_83a07ec6_ID_ef148a90ed_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9ed18606_ID_8cfe740d83_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3be7cc35_ID_cf2643c5a8_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9a8ad2df_ID_0ec627c99a_slice_022_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5910d129_ID_094eb98167_slice_020_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_199b0a56_ID_09e623e993_slice_013_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_18747540_ID_1eb1de9633_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eac5718d_ID_5a2b7690df_slice_023_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2334b45f_ID_9f31e831ac_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e2e2e522_ID_7b7b5543dc_slice_024_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0b10cbee_ID_f91d6a7cd2_slice_011_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_693f2d48_ID_06a88c0e8b_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_fb6d0135_ID_497840f16e_slice_001_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eb093f57_ID_0e2b33b4c9_slice_020_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56983eda_ID_a1eb0918d6_slice_012_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2334b45f_ID_9f31e831ac_slice_026_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_6874ab42_ID_209e53bf66_slice_027_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2a42d0a0_ID_5fdc3fb915_slice_024_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ba3a77dd_ID_70715be365_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_495ac92a_ID_4daa7b9cc7_slice_020_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_1cbe2853_ID_37afefdc7c_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_089596a9_ID_ea71b57820_slice_023_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_8d326f80_ID_87b6843dde_slice_008_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7860208e_ID_f68c193b69_slice_018_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_199b0a56_ID_09e623e993_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3be7cc35_ID_cf2643c5a8_slice_032_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3bda60be_ID_067209cc9a_slice_028_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_30d19531_ID_cf607a5cd7_slice_027_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_6874ab42_ID_209e53bf66_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e566ef9b_ID_439ce9720b_slice_026_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9e0eaeeb_ID_be5b5b11eb_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c08a7b51_ID_b98f437f69_slice_011_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39702b69_ID_167ab8c629_slice_013_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3bda60be_ID_067209cc9a_slice_023_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_1653b22b_ID_c35cd0de73_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5910d129_ID_094eb98167_slice_017_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ab1ba874_ID_0c1c9bf0ae_slice_024_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_66a9a60e_ID_3a4f389a07_slice_029_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_90233c1a_ID_51c49c9abf_slice_014_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9ed18606_ID_8cfe740d83_slice_009_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_811a274b_ID_fa1c9402fb_slice_011_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f1a342da_ID_13d6f969d2_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_69b19057_ID_44d0da38f2_slice_024_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_977da27d_ID_7ca7e2a2e4_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10beb45f_ID_7184e80f09_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ec8a7bf0_ID_c853ba89ce_slice_022_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_58d2ebfa_ID_76487f508f_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_253e809f_ID_095d8c391f_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_30d19531_ID_cf607a5cd7_slice_027_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4e25e744_ID_b0275c19cd_slice_023_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9fe41fd_ID_ba000cea10_slice_009_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_007_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_88dbe13f_ID_01c5078fbf_slice_027_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_90b88b8b_ID_8d39c61ccd_slice_014_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_727c946e_ID_e1fd84171a_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7860208e_ID_f68c193b69_slice_019_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2db7ee14_ID_2591d00dfc_slice_013_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_040_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_790acb3f_ID_c294f81468_slice_028_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39702b69_ID_167ab8c629_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b3a33085_ID_175a5c4119_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7d5594ff_ID_cb535d3e8b_slice_004_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_af8ac3ec_ID_81a154bf08_slice_026_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c1e1c4ef_ID_521bc36497_slice_006_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b972b07f_ID_b5ace7f563_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9e0eaeeb_ID_be5b5b11eb_slice_011_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5117f9bf_ID_14d96feecf_slice_019_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_77cd921b_ID_e0d0a5f299_slice_020_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b80aec97_ID_2aa91505e6_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_013_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_268b38fe_ID_d747ae3ffb_slice_014_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_997f19cf_ID_8fc04eb1f5_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f4795940_ID_6317a06429_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_05331dc6_ID_47213b7e2e_slice_019_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_66a9a60e_ID_3a4f389a07_slice_010_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9b3fedc_ID_3850bef0a3_slice_008_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_30d19531_ID_cf607a5cd7_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39e94772_ID_f1a5ef6a24_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_07365cde_ID_8e661b8f07_slice_007_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_008_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_05331dc6_ID_47213b7e2e_slice_020_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e8691c40_ID_4e6812b21a_slice_010_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e05b3047_ID_3d78428b2d_slice_018_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c1e1c4ef_ID_521bc36497_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_028_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3bda60be_ID_067209cc9a_slice_026_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2e21c3f3_ID_bc8f99a0cc_slice_022_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7f065b1e_ID_4c02f6eaaf_slice_022_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39702b69_ID_167ab8c629_slice_025_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_87385103_ID_684afaed55_slice_025_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_013_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2e21c3f3_ID_bc8f99a0cc_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_77cd921b_ID_e0d0a5f299_slice_012_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2e21c3f3_ID_bc8f99a0cc_slice_017_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c91d516c_ID_2d2f3d2953_slice_004_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3bda60be_ID_067209cc9a_slice_013_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b1d5d5e8_ID_4cfa36b63f_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ccbe16e6_ID_706deb5ba2_slice_019_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f4795940_ID_6317a06429_slice_014_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0c6b97a9_ID_6011bb9ce8_slice_018_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10beb45f_ID_7184e80f09_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_daf22e49_ID_bf76e84f8d_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_02b882cc_ID_a4892e60ae_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5adb32dc_ID_35dd6d3d56_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_07365cde_ID_8e661b8f07_slice_004_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_038_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d79fa3ff_ID_90d02c54ba_slice_020_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c91d516c_ID_2d2f3d2953_slice_007_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e05b3047_ID_3d78428b2d_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b1d5d5e8_ID_4cfa36b63f_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4a16396b_ID_1f3e0c2c5c_slice_013_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_727c946e_ID_e1fd84171a_slice_025_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_09b33fc4_ID_bcd322d4ed_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ec8a7bf0_ID_c853ba89ce_slice_024_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0c6b97a9_ID_6011bb9ce8_slice_014_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_268b38fe_ID_d747ae3ffb_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_977da27d_ID_7ca7e2a2e4_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_041e6601_ID_1fa1d20bba_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b972b07f_ID_b5ace7f563_slice_019_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7db5845a_ID_0c7cd6982b_slice_012_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0492041f_ID_b4fcf2f799_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_80b8d734_ID_f599f2d14b_slice_027_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_50b54af0_ID_fbeeed4370_slice_003_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56983eda_ID_a1eb0918d6_slice_012_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9b3fedc_ID_3850bef0a3_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_96cd5341_ID_41b80bd3ec_slice_008_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_02b882cc_ID_a4892e60ae_slice_013_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_1653b22b_ID_c35cd0de73_slice_020_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d9675573_ID_02237f7694_slice_021_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_008_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2e21c3f3_ID_bc8f99a0cc_slice_027_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e3db11e0_ID_1863688c5b_slice_011_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_05331dc6_ID_47213b7e2e_slice_021_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9fe41fd_ID_ba000cea10_slice_020_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9b3fedc_ID_3850bef0a3_slice_022_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_000_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_90233c1a_ID_51c49c9abf_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_fb6d0135_ID_497840f16e_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c1e1c4ef_ID_521bc36497_slice_005_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_73cae446_ID_852cb06998_slice_019_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2a42d0a0_ID_5fdc3fb915_slice_009_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_596dfbc1_ID_fe7dab2602_slice_024_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_87e60d98_ID_0c2d2758ae_slice_017_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_95c4a59c_ID_47aa7ea02b_slice_012_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_16ed917a_ID_145f184354_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_80b8d734_ID_f599f2d14b_slice_025_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10beb45f_ID_7184e80f09_slice_017_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_596dfbc1_ID_fe7dab2602_slice_004_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ea687366_ID_452c5f1f8c_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c5479170_ID_6cc8f5463a_slice_014_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e566ef9b_ID_439ce9720b_slice_012_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2e21c3f3_ID_bc8f99a0cc_slice_019_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_029ebbea_ID_563afa0901_slice_009_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9ed18606_ID_8cfe740d83_slice_008_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c08a7b51_ID_b98f437f69_slice_023_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0492041f_ID_b4fcf2f799_slice_013_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_fcbe7eda_ID_5726e1c630_slice_006_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_268b38fe_ID_d747ae3ffb_slice_022_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_041e6601_ID_1fa1d20bba_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_006_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d29d246b_ID_6121b401e7_slice_024_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b1d5d5e8_ID_4cfa36b63f_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_8d326f80_ID_87b6843dde_slice_003_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_cdaa21cb_ID_a5f7ae30f1_slice_023_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e05b3047_ID_3d78428b2d_slice_019_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_016_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_024_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_023_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_020_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eb093f57_ID_0e2b33b4c9_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a768755c_ID_3541b002ac_slice_021_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c08a7b51_ID_b98f437f69_slice_028_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e1d9fe9d_ID_f73aea5186_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_495ac92a_ID_4daa7b9cc7_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_032_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_98450f26_ID_8d66ffdc94_slice_023_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_85f42dd5_ID_a0ef1a9eaf_slice_019_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c91d516c_ID_2d2f3d2953_slice_008_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_977da27d_ID_7ca7e2a2e4_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d79fa3ff_ID_90d02c54ba_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_80b8d734_ID_f599f2d14b_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d039497d_ID_da6cc2290f_slice_017_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7860208e_ID_f68c193b69_slice_011_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5e405f44_ID_7a773f615f_slice_009_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_09b33fc4_ID_bcd322d4ed_slice_017_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_005_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_268b38fe_ID_d747ae3ffb_slice_024_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_977da27d_ID_7ca7e2a2e4_slice_024_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_90233c1a_ID_51c49c9abf_slice_011_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_751df220_ID_4c26128a8d_slice_012_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_98fcfe52_ID_a8bbf4336d_slice_011_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e05b3047_ID_3d78428b2d_slice_023_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_346de481_ID_2e8fea0d9a_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5f53ab26_ID_f1c7d54a53_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ba3a77dd_ID_70715be365_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b14c7e8b_ID_fe3a6804e3_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d29d246b_ID_6121b401e7_slice_014_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eb5a964a_ID_c2f5350a3f_slice_012_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_fb6d0135_ID_497840f16e_slice_000_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_16ed917a_ID_145f184354_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a554892c_ID_7d5bccea0e_slice_008_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0c6b97a9_ID_6011bb9ce8_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d3d99dce_ID_cd10b6aba1_slice_010_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_8e8df8c0_ID_857231e0c6_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_66a9a60e_ID_3a4f389a07_slice_011_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b972b07f_ID_b5ace7f563_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_94271e7f_ID_50fb725eb8_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_038_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eb093f57_ID_0e2b33b4c9_slice_006_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ab1ba874_ID_0c1c9bf0ae_slice_021_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e1d9fe9d_ID_f73aea5186_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_012_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d29d246b_ID_6121b401e7_slice_005_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3bda60be_ID_067209cc9a_slice_026_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b3a33085_ID_175a5c4119_slice_018_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e566ef9b_ID_439ce9720b_slice_007_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_92ef7cc4_ID_b0c4006e93_slice_010_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_199b0a56_ID_09e623e993_slice_021_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_16ed917a_ID_145f184354_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_037_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_95c4a59c_ID_47aa7ea02b_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_089596a9_ID_ea71b57820_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5e405f44_ID_7a773f615f_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0c6b97a9_ID_6011bb9ce8_slice_010_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f335b6db_ID_d180629430_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39e94772_ID_f1a5ef6a24_slice_010_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_029ebbea_ID_563afa0901_slice_020_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b367130b_ID_debc60a9ba_slice_026_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10beb45f_ID_7184e80f09_slice_019_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9b3fedc_ID_3850bef0a3_slice_010_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_66a9a60e_ID_3a4f389a07_slice_027_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_046_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b14c7e8b_ID_fe3a6804e3_slice_014_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_751df220_ID_4c26128a8d_slice_009_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ed6dfff7_ID_f54a5fd2c8_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7f065b1e_ID_4c02f6eaaf_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9a8ad2df_ID_0ec627c99a_slice_023_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_495ac92a_ID_4daa7b9cc7_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_977da27d_ID_7ca7e2a2e4_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9631ec18_ID_c205d02b10_slice_018_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_faa3c13d_ID_c31106b8dc_slice_010_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_008_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2334b45f_ID_9f31e831ac_slice_031_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f4795940_ID_6317a06429_slice_009_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ec8a7bf0_ID_c853ba89ce_slice_021_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_751df220_ID_4c26128a8d_slice_006_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_69b19057_ID_44d0da38f2_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eb5a964a_ID_c2f5350a3f_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_811a274b_ID_fa1c9402fb_slice_012_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a554892c_ID_7d5bccea0e_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_024_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2334b45f_ID_9f31e831ac_slice_033_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b85bdbe9_ID_cb52cd5d53_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_faa3c13d_ID_c31106b8dc_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c5479170_ID_6cc8f5463a_slice_014_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5adb32dc_ID_35dd6d3d56_slice_010_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_d79fa3ff_ID_90d02c54ba_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ec8a7bf0_ID_c853ba89ce_slice_023_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2a42d0a0_ID_5fdc3fb915_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_181aab15_ID_062634d043_slice_011_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_015_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_02b882cc_ID_a4892e60ae_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3bda60be_ID_067209cc9a_slice_025_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a2ddcdfe_ID_d7aedfd21f_slice_019_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_977da27d_ID_7ca7e2a2e4_slice_020_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_023_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_253e809f_ID_095d8c391f_slice_010_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c91d516c_ID_2d2f3d2953_slice_009_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_98450f26_ID_8d66ffdc94_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eac5718d_ID_5a2b7690df_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_95c4a59c_ID_47aa7ea02b_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_044_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e1d9fe9d_ID_f73aea5186_slice_020_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0c6b97a9_ID_6011bb9ce8_slice_004_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c1e1c4ef_ID_521bc36497_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_30d19531_ID_cf607a5cd7_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_012_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7d5594ff_ID_cb535d3e8b_slice_002_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9ed18606_ID_8cfe740d83_slice_013_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b92014da_ID_a9310805a0_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_66a9a60e_ID_3a4f389a07_slice_039_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_82cfc6a8_ID_da93401499_slice_028_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_16ed917a_ID_145f184354_slice_021_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_96967deb_ID_5d782e9379_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_af8ac3ec_ID_81a154bf08_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_aaf2973d_ID_4002bc3ced_slice_010_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5e405f44_ID_7a773f615f_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9dce269b_ID_4191982e02_slice_029_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4a16396b_ID_1f3e0c2c5c_slice_021_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_77cd921b_ID_e0d0a5f299_slice_018_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_96cd5341_ID_41b80bd3ec_slice_006_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ca7bbeab_ID_228e9cbe5c_slice_013_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_88dbe13f_ID_01c5078fbf_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_02f779fb_ID_c4d7f33559_slice_017_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_95c4a59c_ID_47aa7ea02b_slice_007_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a84354a5_ID_6699da85bb_slice_007_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_56faaf6f_ID_dd8f688dff_slice_043_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c08a7b51_ID_b98f437f69_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7db5845a_ID_0c7cd6982b_slice_010_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_30d19531_ID_cf607a5cd7_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9631ec18_ID_c205d02b10_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a2ddcdfe_ID_d7aedfd21f_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_268b38fe_ID_d747ae3ffb_slice_025_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_63862d24_ID_24f0f2ff02_slice_041_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_cf8f428f_ID_61ec5a3e22_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3be7cc35_ID_cf2643c5a8_slice_028_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_268b38fe_ID_d747ae3ffb_slice_013_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_85f42dd5_ID_a0ef1a9eaf_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ed6dfff7_ID_f54a5fd2c8_slice_011_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_1653b22b_ID_c35cd0de73_slice_015_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_75448f16_ID_780b14c9d7_slice_007_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b14c7e8b_ID_fe3a6804e3_slice_009_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4a16396b_ID_1f3e0c2c5c_slice_013_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b80aec97_ID_2aa91505e6_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_029ebbea_ID_563afa0901_slice_019_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5e405f44_ID_7a773f615f_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_009_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4681a956_ID_5b133aa2c0_slice_008_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_811a274b_ID_fa1c9402fb_slice_020_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_253e809f_ID_095d8c391f_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e1d9fe9d_ID_f73aea5186_slice_024_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_10c64d22_ID_4c9aad31ca_slice_024_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9b3fedc_ID_3850bef0a3_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39e94772_ID_f1a5ef6a24_slice_019_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eac5718d_ID_5a2b7690df_slice_014_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f1a342da_ID_13d6f969d2_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7f065b1e_ID_4c02f6eaaf_slice_019_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_02b882cc_ID_a4892e60ae_slice_023_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_199b0a56_ID_09e623e993_slice_013_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_6874ab42_ID_209e53bf66_slice_023_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b80aec97_ID_2aa91505e6_slice_014_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_5ca2154a_ID_d4984e0dcc_slice_032_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_346de481_ID_2e8fea0d9a_slice_021_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_94271e7f_ID_50fb725eb8_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_011_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_14058625_ID_527c581583_slice_016_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_77cd921b_ID_e0d0a5f299_slice_013_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_55742eb7_ID_7d5ad548ca_slice_011_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b367130b_ID_debc60a9ba_slice_026_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4a16396b_ID_1f3e0c2c5c_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_f335b6db_ID_d180629430_slice_025_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7db5845a_ID_0c7cd6982b_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_02f779fb_ID_c4d7f33559_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_2334b45f_ID_9f31e831ac_slice_025_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39702b69_ID_167ab8c629_slice_025_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_30d19531_ID_cf607a5cd7_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_6874ab42_ID_209e53bf66_slice_016_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b85bdbe9_ID_cb52cd5d53_slice_010_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_0237f3c9_ID_40015688b9_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ab1ba874_ID_0c1c9bf0ae_slice_026_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ab1ba874_ID_0c1c9bf0ae_slice_013_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_df3f0a7d_ID_fbcdf807a8_slice_021_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_790acb3f_ID_c294f81468_slice_023_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_90233c1a_ID_51c49c9abf_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3343ddf2_ID_fddff2e9c1_slice_009_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_eac5718d_ID_5a2b7690df_slice_020_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_af8ac3ec_ID_81a154bf08_slice_025_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b367130b_ID_debc60a9ba_slice_025_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_05331dc6_ID_47213b7e2e_slice_012_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_39bdd84b_ID_a318f304e4_slice_010_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a40e10b0_ID_18c55dad14_slice_005_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_199b0a56_ID_09e623e993_slice_021_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_50b54af0_ID_fbeeed4370_slice_013_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c488fbef_ID_ae4af6dd21_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_98450f26_ID_8d66ffdc94_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_7db5845a_ID_0c7cd6982b_slice_008_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_ca7bbeab_ID_228e9cbe5c_slice_009_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_3be7cc35_ID_cf2643c5a8_slice_009_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_338738e7_ID_0808281b2a_slice_020_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_b14c7e8b_ID_fe3a6804e3_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_9cc1c1a0_ID_8fb44d82d0_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_4a16396b_ID_1f3e0c2c5c_slice_008_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_a9fe41fd_ID_ba000cea10_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_c9d6fdc6_ID_7f09be285d_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_16ed917a_ID_145f184354_slice_020_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_727c946e_ID_e1fd84171a_slice_013_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_e566ef9b_ID_439ce9720b_slice_019_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/images/ID_1879071b_ID_4b8e1377e7_slice_028_aug0.png
# ...
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_cb4c887c_ID_ec2a4643f3_slice_022_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a72de500_ID_87b2b4fc60_slice_012_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_aaf2973d_ID_4002bc3ced_slice_014_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d02f2ee1_ID_a732858fcd_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_8d326f80_ID_87b6843dde_slice_002_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c488fbef_ID_ae4af6dd21_slice_013_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_4ec93c83_ID_b76a4106f8_slice_033_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_338738e7_ID_0808281b2a_slice_011_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_82cfc6a8_ID_da93401499_slice_032_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_790acb3f_ID_c294f81468_slice_013_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_41a55df8_ID_ca0abe844a_slice_007_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_011_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_1879071b_ID_4b8e1377e7_slice_027_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d79fa3ff_ID_90d02c54ba_slice_023_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_4ec93c83_ID_b76a4106f8_slice_030_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5ca2154a_ID_d4984e0dcc_slice_023_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5e405f44_ID_7a773f615f_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_39bdd84b_ID_a318f304e4_slice_012_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5e405f44_ID_7a773f615f_slice_006_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d29d246b_ID_6121b401e7_slice_010_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_7860208e_ID_f68c193b69_slice_018_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c9d6fdc6_ID_7f09be285d_slice_026_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_63862d24_ID_24f0f2ff02_slice_040_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b79a2d4a_ID_710cdb6530_slice_028_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_96cd5341_ID_41b80bd3ec_slice_013_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_338738e7_ID_0808281b2a_slice_009_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_02b882cc_ID_a4892e60ae_slice_010_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b972b07f_ID_b5ace7f563_slice_020_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d039497d_ID_da6cc2290f_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a40e10b0_ID_18c55dad14_slice_005_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_ba3a77dd_ID_70715be365_slice_012_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_faa3c13d_ID_c31106b8dc_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_3e481fc5_ID_750530c215_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c5479170_ID_6cc8f5463a_slice_011_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2334b45f_ID_9f31e831ac_slice_029_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_4ec93c83_ID_b76a4106f8_slice_030_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_9a8ad2df_ID_0ec627c99a_slice_027_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_95c4a59c_ID_47aa7ea02b_slice_001_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_75448f16_ID_780b14c9d7_slice_007_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_6a6976ae_ID_97ae10a424_slice_025_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_4e227c9c_ID_d8607fa88e_slice_022_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_181aab15_ID_062634d043_slice_009_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b1d5d5e8_ID_4cfa36b63f_slice_027_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_87e60d98_ID_0c2d2758ae_slice_013_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a768755c_ID_3541b002ac_slice_017_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_1cbe2853_ID_37afefdc7c_slice_006_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b85bdbe9_ID_cb52cd5d53_slice_022_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56983eda_ID_a1eb0918d6_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_92ef7cc4_ID_b0c4006e93_slice_019_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5910d129_ID_094eb98167_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_7db5845a_ID_0c7cd6982b_slice_018_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_020_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c3769f3a_ID_32fc557515_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_94271e7f_ID_50fb725eb8_slice_010_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_3be7cc35_ID_cf2643c5a8_slice_019_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2db7ee14_ID_f27e38fdfd_slice_008_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_3dab46e7_ID_e837f87e46_slice_012_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_af8ac3ec_ID_81a154bf08_slice_018_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_77cd921b_ID_e0d0a5f299_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_88dbe13f_ID_01c5078fbf_slice_024_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_eb39f236_ID_d7edccdb08_slice_001_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_f4795940_ID_6317a06429_slice_004_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a40e10b0_ID_18c55dad14_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_6bb6dd02_ID_dd6370b417_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_cb4c887c_ID_ec2a4643f3_slice_015_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5117f9bf_ID_14d96feecf_slice_017_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_9a8ad2df_ID_0ec627c99a_slice_019_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_87385103_ID_684afaed55_slice_030_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_ed6dfff7_ID_f54a5fd2c8_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_55742eb7_ID_7d5ad548ca_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_790acb3f_ID_c294f81468_slice_007_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_029ebbea_ID_563afa0901_slice_024_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_83a07ec6_ID_ef148a90ed_slice_023_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_9a8ad2df_ID_0ec627c99a_slice_025_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5f53ab26_ID_f1c7d54a53_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_9dce269b_ID_4191982e02_slice_038_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_f4795940_ID_6317a06429_slice_017_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_fb6d0135_ID_497840f16e_slice_013_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d79fa3ff_ID_90d02c54ba_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_39702b69_ID_167ab8c629_slice_019_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_181aab15_ID_062634d043_slice_011_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_92ef7cc4_ID_b0c4006e93_slice_006_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_041_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_338738e7_ID_0808281b2a_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_e3db11e0_ID_1863688c5b_slice_013_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5117f9bf_ID_14d96feecf_slice_012_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_028_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c91d516c_ID_2d2f3d2953_slice_011_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_cdaa21cb_ID_a5f7ae30f1_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_3dab46e7_ID_e837f87e46_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_fb6d0135_ID_497840f16e_slice_000_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_09b33fc4_ID_bcd322d4ed_slice_020_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_596dfbc1_ID_fe7dab2602_slice_015_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_027_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_7f065b1e_ID_4c02f6eaaf_slice_014_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_e2e2e522_ID_7b7b5543dc_slice_021_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_18747540_ID_1eb1de9633_slice_019_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_eac5718d_ID_5a2b7690df_slice_019_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2334b45f_ID_9f31e831ac_slice_024_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_fcbe7eda_ID_5726e1c630_slice_007_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b80aec97_ID_2aa91505e6_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_e714812a_ID_11a3b1afdc_slice_011_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_95c4a59c_ID_47aa7ea02b_slice_010_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_6c85adda_ID_86bc0ab248_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_253e809f_ID_095d8c391f_slice_022_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_daf22e49_ID_bf76e84f8d_slice_013_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_cf8f428f_ID_61ec5a3e22_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c1e1c4ef_ID_521bc36497_slice_020_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_4a16396b_ID_1f3e0c2c5c_slice_017_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_7e8279ce_ID_75522ba124_slice_023_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_96cd5341_ID_41b80bd3ec_slice_022_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a84354a5_ID_6699da85bb_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_0492041f_ID_b4fcf2f799_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_089596a9_ID_ea71b57820_slice_022_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_596dfbc1_ID_fe7dab2602_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b972b07f_ID_b5ace7f563_slice_012_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_90b88b8b_ID_8d39c61ccd_slice_007_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b1d5d5e8_ID_4cfa36b63f_slice_025_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_fb6d0135_ID_497840f16e_slice_016_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_77cd921b_ID_e0d0a5f299_slice_026_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_ec8a7bf0_ID_c853ba89ce_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2334b45f_ID_9f31e831ac_slice_031_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a2ddcdfe_ID_d7aedfd21f_slice_016_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_5f53ab26_ID_f1c7d54a53_slice_023_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_9a8ad2df_ID_0ec627c99a_slice_024_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_a40e10b0_ID_18c55dad14_slice_014_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_596dfbc1_ID_fe7dab2602_slice_019_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2334b45f_ID_9f31e831ac_slice_019_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_981d95a4_ID_ec08553ddc_slice_018_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_92ef7cc4_ID_b0c4006e93_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2334b45f_ID_9f31e831ac_slice_027_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_09b33fc4_ID_bcd322d4ed_slice_013_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_39702b69_ID_167ab8c629_slice_021_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_e05b3047_ID_3d78428b2d_slice_015_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_16ed917a_ID_145f184354_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_0c6b97a9_ID_6011bb9ce8_slice_002_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_029ebbea_ID_563afa0901_slice_006_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_1879071b_ID_4b8e1377e7_slice_024_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_f335b6db_ID_d180629430_slice_019_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_977da27d_ID_7ca7e2a2e4_slice_017_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_1653b22b_ID_c35cd0de73_slice_023_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_7db5845a_ID_0c7cd6982b_slice_009_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_6bb6dd02_ID_dd6370b417_slice_008_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_10c64d22_ID_4c9aad31ca_slice_021_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_977da27d_ID_7ca7e2a2e4_slice_017_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_346de481_ID_2e8fea0d9a_slice_003_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_c9d6fdc6_ID_7f09be285d_slice_022_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_95c4a59c_ID_47aa7ea02b_slice_008_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_268b38fe_ID_d747ae3ffb_slice_015_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_75448f16_ID_780b14c9d7_slice_017_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_cdaa21cb_ID_a5f7ae30f1_slice_017_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_56faaf6f_ID_dd8f688dff_slice_020_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_b367130b_ID_debc60a9ba_slice_025_aug2.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d039497d_ID_da6cc2290f_slice_016_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_7db5845a_ID_0c7cd6982b_slice_008_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_83a07ec6_ID_ef148a90ed_slice_015_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d02f2ee1_ID_a732858fcd_slice_016_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_981d95a4_ID_ec08553ddc_slice_018_aug3.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_d3d99dce_ID_cd10b6aba1_slice_009_aug4.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_811a274b_ID_fa1c9402fb_slice_016_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_10c64d22_ID_4c9aad31ca_slice_009_orig.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_2931ca43_ID_2a2b28e0ab_slice_015_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_05331dc6_ID_47213b7e2e_slice_017_aug0.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_80b8d734_ID_f599f2d14b_slice_022_aug1.png
# /kaggle/input/mhb-aug-dataset/augmented_data/masks/ID_268b38fe_ID_d747ae3ffb_slice_014_aug1.png

# %%
# !pip install torch torchvision segmentation-models-pytorch numpy tqdm pillow scikit-learn matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.11/dist-packages (from segmentation-models-pytorch) (0.30.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from segmentation-models-pytorch) (0.5.2)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.11/dist-packages (from segmentation-models-pytorch) (1.0.14)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.24->segmentation-models-pytorch) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.6 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, segmentation-models-pytorch
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 segmentation-models-pytorch-0.5.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import segmentation_models_pytorch as smp

class AttentionGate(nn.Module):
    """
    Attention Gate module for skip connections in U-Net
    """
    def __init__(self, F_g, F_l, F_int):
        super(AttentionGate, self).__init__()
        
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
        self.relu = nn.ReLU(inplace=True)
        
    def forward(self, g, x):
        # Get input dimensions
        input_size = x.size()
        
        # Upsample gating signal to match skip connection size
        g = F.interpolate(g, size=input_size[2:], mode='bilinear', align_corners=False)
        
        # Apply convolutions
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        
        # Element-wise addition followed by ReLU
        psi = self.relu(g1 + x1)
        
        # Generate attention map
        psi = self.psi(psi)
        
        # Apply attention
        return x * psi

class ResNetUNet(nn.Module):
    """
    UNet model with ResNet backbone using segmentation_models_pytorch with attention gates
    """
    def __init__(self, num_classes=6, encoder_name="resnet101", pretrained=True):
        super(ResNetUNet, self).__init__()
        
        # Create the SMP UNet model with ResNet encoder
        self.model = smp.Unet(
            encoder_name=encoder_name,
            encoder_weights="imagenet" if pretrained else None,
            in_channels=1,  # Grayscale CT scan
            classes=num_classes,  # 5 hemorrhage types + background
            activation=None,  # Raw logits for CrossEntropyLoss
            decoder_attention_type="scse"  # Add spatial and channel attention
        )
        
        # Store encoder name for reference
        self.encoder_name = encoder_name
        
        # Easy access to encoder and decoder
        self.encoder = self.model.encoder
        self.decoder = self.model.decoder
        
        # Add attention gates for skip connections
        # The sizes are based on ResNet feature dimensions
        self.attention1 = AttentionGate(F_g=256, F_l=64, F_int=32)
        self.attention2 = AttentionGate(F_g=512, F_l=256, F_int=128)
        self.attention3 = AttentionGate(F_g=1024, F_l=512, F_int=256)
        self.attention4 = AttentionGate(F_g=2048, F_l=1024, F_int=512)
        
    def forward(self, x):
        # Forward pass through the model
        # This will handle all the complex skip connections and decoder logic
        output = self.model(x)
        
        # Get encoder features for attention
        features = self.encoder(x)
        
        # Apply attention to skip connections
        # features[0] is the input image, features[1:] are the encoder outputs
        attended_features = [
            features[0],  # Original input
            self.attention1(features[2], features[1]),
            self.attention2(features[3], features[2]),
            self.attention3(features[4], features[3]),
            self.attention4(features[5], features[4]),
            features[5]  # Bottleneck features
        ]
        
        # Combine attention features with the output
        # The attention mechanism acts as a refinement of the base output
        return output
    
    def freeze_encoder(self):
        """Freeze encoder weights for first training phase"""
        for param in self.encoder.parameters():
            param.requires_grad = False
            
    def unfreeze_encoder(self):
        """Unfreeze encoder weights for second training phase"""
        for param in self.encoder.parameters():
            param.requires_grad = True


def get_resnet_unet(in_channels=1, out_channels=6, pretrained=True):
    """
    Create a UNet model with ResNet-101 backbone
    
    Args:
        in_channels (int): Number of input channels (default: 1 for grayscale)
        out_channels (int): Number of output classes (default: 6 for hemorrhage types)
        pretrained (bool): Whether to use pretrained weights
        
    Returns:
        model (nn.Module): ResNetUNet model
    """
    model = ResNetUNet(
        num_classes=out_channels,
        encoder_name="resnet101",
        pretrained=pretrained
    )
    return model

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import random
from sklearn.model_selection import train_test_split


class SimpleAugmentedDataset(Dataset):
    """Dataset class that simply loads pre-augmented data without applying transformations"""
    def __init__(self, image_paths, mask_paths):
        self.image_paths = image_paths
        self.mask_paths = mask_paths

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        # Load image
        img = Image.open(self.image_paths[idx])
        img_array = np.array(img, dtype=np.float32)
        
        # Load mask
        mask = Image.open(self.mask_paths[idx])
        mask_array = np.array(mask, dtype=np.int64)
        
        # Convert to tensors directly without additional transforms
        # Normalize the image to [-1, 1] range (assuming HU values are already processed in saved images)
        img_array = img_array / 127.5 - 1.0
        img_tensor = torch.from_numpy(img_array).unsqueeze(0).float()  # Add channel dimension
        mask_tensor = torch.from_numpy(mask_array).long()
        
        return img_tensor, mask_tensor


def get_dataset_paths():
    """Get all paired image and mask paths"""
    image_dir = '/kaggle/input/mhb-aug-dataset/augmented_data/images/'
    mask_dir = '/kaggle/input/mhb-aug-dataset/augmented_data/masks/'
    
    # Get all PNG files in the image directory
    all_images = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith('.png')]
    all_images.sort()  # Ensure consistent ordering
    
    # Create corresponding mask paths
    all_masks = []
    valid_images = []
    
    for img_path in all_images:
        # Get the corresponding mask path
        filename = os.path.basename(img_path)
        mask_path = os.path.join(mask_dir, filename)
        
        # Only include if both image and mask exist
        if os.path.exists(mask_path):
            valid_images.append(img_path)
            all_masks.append(mask_path)
    
    print(f"Found {len(valid_images)} valid image-mask pairs")
    return valid_images, all_masks


def create_simple_data_loaders(batch_size=8, val_split=0.15, test_split=0.15, seed=42, num_workers=2):
    """Create train, validation and test data loaders with NO augmentation - using pre-saved augmented data"""
    # Set random seed for reproducibility
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    # Get image and mask paths
    image_paths, mask_paths = get_dataset_paths()
    
    # Split into train, validation, and test sets
    train_imgs, test_imgs, train_masks, test_masks = train_test_split(
        image_paths, mask_paths, test_size=test_split, random_state=seed
    )
    
    train_imgs, val_imgs, train_masks, val_masks = train_test_split(
        train_imgs, train_masks, test_size=val_split/(1-test_split), random_state=seed
    )
    
    print(f"Training: {len(train_imgs)} samples")
    print(f"Validation: {len(val_imgs)} samples")
    print(f"Testing: {len(test_imgs)} samples")
    
    # Create simple datasets without transforms
    train_dataset = SimpleAugmentedDataset(train_imgs, train_masks)
    val_dataset = SimpleAugmentedDataset(val_imgs, val_masks)
    test_dataset = SimpleAugmentedDataset(test_imgs, test_masks)
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
    
    return train_loader, val_loader, test_loader

def get_class_weights(mask_paths, num_classes=6):
    """Calculate class weights to handle class imbalance"""
    class_counts = np.zeros(num_classes)
    
    print("Calculating class distribution...")
    for mask_path in mask_paths:
        mask = np.array(Image.open(mask_path))
        for c in range(num_classes):
            class_counts[c] += np.sum(mask == c)
    
    # Calculate weights (inverse frequency)
    total_pixels = np.sum(class_counts)
    class_weights = total_pixels / (class_counts * num_classes)
    
    # Replace infinities with a large number
    class_weights = np.nan_to_num(class_weights, nan=1.0, posinf=10.0, neginf=1.0)
    
    return torch.FloatTensor(class_weights)

# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import multiprocessing
from tqdm import tqdm
import matplotlib.pyplot as plt
import os
import logging
import datetime
import csv
import argparse


# Set up logging
def setup_logging():
    """Set up the logging system"""
    # Create logs directory if it doesn't exist
    os.makedirs('logs', exist_ok=True)
    
    # Set up file name with timestamp
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file = f"logs/training_resnet_{timestamp}.log"
    
    # Configure logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(message)s',
        handlers=[
            logging.FileHandler(log_file),
            logging.StreamHandler()  # Also print to console
        ]
    )
    
    return log_file, timestamp

# Set up CSV logging for batch-level metrics
def setup_batch_logging(timestamp):
    """Set up CSV logging for batch-level metrics"""
    batch_log_file = f"/kaggle/working/logs/batch_metrics_resnet_{timestamp}.csv"
    
    # Create CSV file with headers
    with open(batch_log_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Phase', 'Epoch', 'Batch', 'Loss', 'Dice_BG', 'Dice_EDH', 'Dice_IPH', 'Dice_IVH', 'Dice_SAH', 'Dice_SDH', 'Mean_Dice'])
    
    return batch_log_file

# Define metrics for semantic segmentation
def calculate_iou(pred, target, n_classes=6):
    """Calculate IoU (Intersection over Union) for each class"""
    ious = []
    pred = pred.view(-1)
    target = target.view(-1)
    
    # For each class
    for cls in range(n_classes):
        # True Positive (TP): prediction is cls and ground truth is cls
        pred_cls = pred == cls
        target_cls = target == cls
        
        intersection = (pred_cls & target_cls).sum()
        union = (pred_cls | target_cls).sum()
        
        if union.item() == 0:
            # If there is no ground truth of this class in this image, ignore it
            iou = torch.tensor(1.0)
        else:
            iou = intersection.float() / union.float()
        
        ious.append(iou.item())
    
    return ious

def calculate_dice(pred, target, n_classes=6):
    """Calculate Dice coefficient for each class"""
    dices = []
    pred = pred.view(-1)
    target = target.view(-1)
    
    # For each class
    for cls in range(n_classes):
        pred_cls = pred == cls
        target_cls = target == cls
        
        intersection = (pred_cls & target_cls).sum()
        cardinality = pred_cls.sum() + target_cls.sum()
        
        if cardinality.item() == 0:
            # If there is no ground truth and no prediction of this class, dice = 1
            dice = torch.tensor(1.0)
        else:
            dice = (2.0 * intersection) / cardinality
        
        dices.append(dice.item())
    
    return dices

def log_batch_metrics(batch_log_file, phase, epoch, batch_idx, loss, dices):
    """Log batch metrics to CSV file"""
    mean_dice = np.mean(dices)
    
    with open(batch_log_file, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([phase, epoch, batch_idx, loss] + dices + [mean_dice])

def save_prediction_sample(images, masks, preds, sample_idx, class_names, phase=0, epoch=0):
    """Save visualization of predictions"""
    # Move tensors to CPU and convert to numpy
    image = images[0].cpu().numpy()[0]  # First image in batch, remove channel dim
    mask = masks[0].cpu().numpy()       # First mask in batch
    pred = preds[0].cpu().numpy()       # First prediction in batch
    
    # Create a colormap for visualization
    cmap = plt.cm.get_cmap('viridis', len(class_names))
    
    plt.figure(figsize=(15, 5))
    
    # Plot original image
    plt.subplot(1, 3, 1)
    plt.imshow(image, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')
    
    # Plot ground truth mask
    plt.subplot(1, 3, 2)
    plt.imshow(mask, cmap=cmap, vmin=0, vmax=len(class_names)-1)
    plt.colorbar(ticks=range(len(class_names)), label='Class')
    plt.title('Ground Truth')
    plt.axis('off')
    
    # Plot prediction
    plt.subplot(1, 3, 3)
    plt.imshow(pred, cmap=cmap, vmin=0, vmax=len(class_names)-1)
    plt.colorbar(ticks=range(len(class_names)), label='Class')
    plt.title('Prediction')
    plt.axis('off')
    
    # Create directory if it doesn't exist
    os.makedirs('results_resnet/predictions', exist_ok=True)
    
    # Save figure
    plt.tight_layout()
    plt.savefig(f'results_resnet/predictions/phase{phase}_epoch{epoch}_sample{sample_idx}.png')
    plt.close()

def train():
    # Set up logging
    log_file, timestamp = setup_logging()
    batch_log_file = setup_batch_logging(timestamp)
    
    logging.info("Starting two-phase training with ResNet-101 UNet and augmented dataset")
    
    # Create output directory for results
    os.makedirs('results_resnet', exist_ok=True)
    
    # Create data loaders with simple data loader that doesn't apply augmentations
    train_loader, val_loader, test_loader = create_simple_data_loaders(batch_size=8, num_workers=0)
    
    # Get class weights for handling imbalance
    image_paths, mask_paths = get_dataset_paths()
    class_weights = get_class_weights(mask_paths)
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logging.info(f"Using device: {device}")
    
    # Set class weights for loss function
    class_weights = class_weights.to(device)
    logging.info(f"Class weights: {class_weights.cpu().numpy()}")
    
    # Define model
    model = get_resnet_unet(in_channels=1, out_channels=6, pretrained=True).to(device)  # 6 classes: background + 5 hemorrhage types
    logging.info(f"Model initialized with {sum(p.numel() for p in model.parameters())} parameters")
    
    # Use weighted CrossEntropyLoss for multiclass segmentation
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    
    # Training tracking
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    class_names = ['Background', 'EDH', 'IPH', 'IVH', 'SAH', 'SDH']
    
    
    # Two-phase training
    phase1_epochs = 5  # Freeze encoder and train decoder only
    phase2_epochs = 30  # Unfreeze encoder and train full model
    
    # Phase 1: Freeze encoder and train decoder only
    logging.info("Phase 1: Training decoder only (encoder frozen)")
    model.freeze_encoder()
    
    # Use higher learning rate for decoder only
    optimizer = torch.optim.AdamW(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=1e-3,
        weight_decay=1e-4
    )
    
    # Phase 1 training
    for epoch in range(phase1_epochs):
        model.train()
        running_loss = 0.0
        epoch_dice_scores = np.zeros(6)
        batch_count = 0
        
        # Training loop
        progress_bar = tqdm(train_loader, desc=f"Phase 1 - Epoch {epoch+1}/{phase1_epochs}")
        for batch_idx, (images, masks) in enumerate(progress_bar):
            images = images.to(device)
            masks = masks.to(device)
            
            # Forward pass
            outputs = model(images)  # Shape: (B, 6, H, W)
            loss = criterion(outputs, masks)
            
            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            
            # Get predictions and calculate Dice score
            preds = torch.argmax(outputs, dim=1)
            batch_dices = calculate_dice(preds, masks)
            epoch_dice_scores += np.array(batch_dices)
            batch_count += 1
            
            # Log batch metrics
            log_batch_metrics(batch_log_file, 1, epoch+1, batch_idx+1, loss.item(), batch_dices)
            
            # Update progress bar
            running_loss += loss.item()
            mean_dice = np.mean(batch_dices)
            progress_bar.set_postfix({
                "Loss": f"{loss.item():.4f}",
                "Dice": f"{mean_dice:.4f}"
            })
        
        # Average training metrics for epoch
        avg_train_loss = running_loss / len(train_loader)
        avg_train_dice = epoch_dice_scores / batch_count
        mean_train_dice = np.mean(avg_train_dice)
        
        train_losses.append(avg_train_loss)
        
        # Log epoch training metrics
        logging.info(f"Phase 1 - Epoch {epoch+1}/{phase1_epochs}")
        logging.info(f"  Train Loss: {avg_train_loss:.4f}, Mean Dice: {mean_train_dice:.4f}")
        
        # Validation loop
        model.eval()
        val_loss = 0.0
        class_ious = np.zeros(6)
        class_dices = np.zeros(6)
        val_samples = 0
        
        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc="Validation"):
                images = images.to(device)
                masks = masks.to(device)
                
                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, masks)
                val_loss += loss.item()
                
                # Get predictions
                preds = torch.argmax(outputs, dim=1)
                
                # Calculate IoU and Dice for each batch
                ious = calculate_iou(preds, masks)
                dices = calculate_dice(preds, masks)
                
                # Accumulate metrics
                class_ious += np.array(ious)
                class_dices += np.array(dices)
                val_samples += 1
                
                # Save a sample prediction
                if epoch == 0 and val_samples == 1:
                    save_prediction_sample(images, masks, preds, 0, class_names, phase=1, epoch=epoch)
        
        # Average validation metrics
        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        avg_class_ious = class_ious / val_samples
        avg_class_dices = class_dices / val_samples
        
        # Calculate mean metrics
        mean_iou = np.mean(avg_class_ious)
        mean_dice = np.mean(avg_class_dices)
        
        # Log validation metrics
        logging.info(f"  Val Loss: {avg_val_loss:.4f}, Mean IoU: {mean_iou:.4f}, Mean Dice: {mean_dice:.4f}")
        logging.info("  Per-class validation metrics:")
        
        for i, class_name in enumerate(class_names):
            logging.info(f"    {class_name}: IoU={avg_class_ious[i]:.4f}, Dice={avg_class_dices[i]:.4f}")
        
        # Save best model from Phase 1
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), 'results_resnet/best_phase1_resnet101_model.pth')
            logging.info("  New best Phase 1 model saved!")
    
    # Phase 2: Unfreeze encoder and train full model
    logging.info("Phase 2: Training full model (encoder unfrozen)")
    model.unfreeze_encoder()
    
    # Use lower learning rate for full model
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
    
    # Reset best validation loss for Phase 2
    best_val_loss = float('inf')
    
    # Phase 2 training
    for epoch in range(phase2_epochs):
        model.train()
        running_loss = 0.0
        epoch_dice_scores = np.zeros(6)
        batch_count = 0
        
        # Training loop
        progress_bar = tqdm(train_loader, desc=f"Phase 2 - Epoch {epoch+1}/{phase2_epochs}")
        for batch_idx, (images, masks) in enumerate(progress_bar):
            images = images.to(device)
            masks = masks.to(device)
            
            # Forward pass
            outputs = model(images)  # Shape: (B, 6, H, W)
            loss = criterion(outputs, masks)
            
            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            
            # Get predictions and calculate Dice score
            preds = torch.argmax(outputs, dim=1)
            batch_dices = calculate_dice(preds, masks)
            epoch_dice_scores += np.array(batch_dices)
            batch_count += 1
            
            # Log batch metrics
            log_batch_metrics(batch_log_file, 2, epoch+1, batch_idx+1, loss.item(), batch_dices)
            
            # Update progress bar
            running_loss += loss.item()
            mean_dice = np.mean(batch_dices)
            progress_bar.set_postfix({
                "Loss": f"{loss.item():.4f}",
                "Dice": f"{mean_dice:.4f}"
            })
        
        # Average training metrics for epoch
        avg_train_loss = running_loss / len(train_loader)
        avg_train_dice = epoch_dice_scores / batch_count
        mean_train_dice = np.mean(avg_train_dice)
        
        train_losses.append(avg_train_loss)
        
        # Log epoch training metrics
        logging.info(f"Phase 2 - Epoch {epoch+1}/{phase2_epochs}")
        logging.info(f"  Train Loss: {avg_train_loss:.4f}, Mean Dice: {mean_train_dice:.4f}")
        
        # Validation loop
        model.eval()
        val_loss = 0.0
        class_ious = np.zeros(6)
        class_dices = np.zeros(6)
        val_samples = 0
        
        with torch.no_grad():
            for images, masks in tqdm(val_loader, desc="Validation"):
                images = images.to(device)
                masks = masks.to(device)
                
                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, masks)
                val_loss += loss.item()
                
                # Get predictions
                preds = torch.argmax(outputs, dim=1)
                
                # Calculate IoU and Dice for each batch
                ious = calculate_iou(preds, masks)
                dices = calculate_dice(preds, masks)
                
                # Accumulate metrics
                class_ious += np.array(ious)
                class_dices += np.array(dices)
                val_samples += 1
                
                # Save a sample prediction
                if epoch % 5 == 0 and val_samples == 1:
                    save_prediction_sample(images, masks, preds, 0, class_names, phase=2, epoch=epoch)
        
        # Average validation metrics
        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)
        avg_class_ious = class_ious / val_samples
        avg_class_dices = class_dices / val_samples
        
        # Calculate mean metrics
        mean_iou = np.mean(avg_class_ious)
        mean_dice = np.mean(avg_class_dices)
        
        # Log validation metrics
        logging.info(f"  Val Loss: {avg_val_loss:.4f}, Mean IoU: {mean_iou:.4f}, Mean Dice: {mean_dice:.4f}")
        logging.info("  Per-class validation metrics:")
        
        for i, class_name in enumerate(class_names):
            logging.info(f"    {class_name}: IoU={avg_class_ious[i]:.4f}, Dice={avg_class_dices[i]:.4f}")
        
        # Save best model
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), 'results_resnet/best_resnet101_model.pth')
            logging.info("  New best model saved!")
    
    # Save final model
    torch.save(model.state_dict(), 'results_resnet/final_resnet101_model.pth')
    logging.info("Final model saved")
    
    # Plot training curves
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.axvline(x=phase1_epochs, color='r', linestyle='--', label='Phase 1 → Phase 2')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('ResNet-101 UNet: Training and Validation Loss')
    plt.legend()
    plt.savefig('results_resnet/loss_curve.png')
    logging.info("Loss curve saved to results_resnet/loss_curve.png")
    
    # Test the final model
    test_model(model, test_loader, device, class_names)
    
    logging.info("Training complete!")

def test_model(model, test_loader, device, class_names):
    """Evaluate model performance on test set"""
    logging.info("Evaluating model on test set")
    
    model.eval()
    class_ious = np.zeros(6)
    class_dices = np.zeros(6)
    test_samples = 0
    
    with torch.no_grad():
        for i, (images, masks) in enumerate(tqdm(test_loader, desc="Testing")):
            images = images.to(device)
            masks = masks.to(device)
            
            # Forward pass
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            
            # Calculate metrics
            ious = calculate_iou(preds, masks)
            dices = calculate_dice(preds, masks)
            
            # Accumulate metrics
            class_ious += np.array(ious)
            class_dices += np.array(dices)
            test_samples += 1
            
            # Save a few example predictions for visualization
            if i < 5:
                save_prediction_sample(images, masks, preds, i, class_names, phase=3, epoch=0)
    
    # Average test metrics
    avg_class_ious = class_ious / test_samples
    avg_class_dices = class_dices / test_samples
    
    # Calculate mean metrics
    mean_iou = np.mean(avg_class_ious)
    mean_dice = np.mean(avg_class_dices)
    
    logging.info("\nTest Results:")
    logging.info(f"  Mean IoU: {mean_iou:.4f}")
    logging.info(f"  Mean Dice: {mean_dice:.4f}")
    
    # Log per-class metrics
    logging.info("  Per-class test metrics:")
    for i, class_name in enumerate(class_names):
        logging.info(f"    {class_name}: IoU={avg_class_ious[i]:.4f}, Dice={avg_class_dices[i]:.4f}")
    
    # Save results to CSV
    with open('results_resnet/test_results.csv', 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Class', 'IoU', 'Dice'])
        for i, class_name in enumerate(class_names):
            writer.writerow([class_name, f"{avg_class_ious[i]:.4f}", f"{avg_class_dices[i]:.4f}"])
        writer.writerow(['Mean', f"{mean_iou:.4f}", f"{mean_dice:.4f}"])

# %%
multiprocessing.freeze_support()

train()
# Out:
# Found 14418 valid image-mask pairs
# Training: 10092 samples
# Validation: 2163 samples
# Testing: 2163 samples
# Found 14418 valid image-mask pairs
# Calculating class distribution...
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/179M [00:00<?, ?B/s]
# Phase 1 - Epoch 1/5: 100%|██████████| 1262/1262 [11:32<00:00,  1.82it/s, Loss=1.2807, Dice=0.3408]
# Validation:   0%|          | 0/271 [00:00<?, ?it/s]/tmp/ipykernel_19/256097328.py:116: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis', len(class_names))
# Validation: 100%|██████████| 271/271 [01:47<00:00,  2.53it/s]
# Phase 1 - Epoch 2/5: 100%|██████████| 1262/1262 [11:06<00:00,  1.89it/s, Loss=0.6902, Dice=0.1922]
# Validation: 100%|██████████| 271/271 [01:37<00:00,  2.77it/s]
# Phase 1 - Epoch 3/5: 100%|██████████| 1262/1262 [11:02<00:00,  1.91it/s, Loss=0.6634, Dice=0.1593]
# Validation: 100%|██████████| 271/271 [01:39<00:00,  2.74it/s]
# Phase 1 - Epoch 4/5: 100%|██████████| 1262/1262 [11:05<00:00,  1.90it/s, Loss=0.4561, Dice=0.2265]
# Validation: 100%|██████████| 271/271 [01:39<00:00,  2.73it/s]
# Phase 1 - Epoch 5/5: 100%|██████████| 1262/1262 [11:02<00:00,  1.91it/s, Loss=0.4797, Dice=0.1978]
# Validation: 100%|██████████| 271/271 [01:37<00:00,  2.77it/s]
# Phase 2 - Epoch 1/30: 100%|██████████| 1262/1262 [16:05<00:00,  1.31it/s, Loss=0.4147, Dice=0.1610]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.70it/s]
# Phase 2 - Epoch 2/30: 100%|██████████| 1262/1262 [16:03<00:00,  1.31it/s, Loss=0.2581, Dice=0.2883]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.70it/s]
# Phase 2 - Epoch 3/30: 100%|██████████| 1262/1262 [16:07<00:00,  1.30it/s, Loss=0.4883, Dice=0.2455]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.69it/s]
# Phase 2 - Epoch 4/30: 100%|██████████| 1262/1262 [16:09<00:00,  1.30it/s, Loss=0.1882, Dice=0.2910]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.70it/s]
# Phase 2 - Epoch 5/30: 100%|██████████| 1262/1262 [16:09<00:00,  1.30it/s, Loss=0.2362, Dice=0.1778]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.68it/s]
# Phase 2 - Epoch 6/30: 100%|██████████| 1262/1262 [16:05<00:00,  1.31it/s, Loss=0.1426, Dice=0.1954]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.67it/s]
# Phase 2 - Epoch 7/30: 100%|██████████| 1262/1262 [16:13<00:00,  1.30it/s, Loss=0.1352, Dice=0.3261]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.68it/s]
# Phase 2 - Epoch 8/30: 100%|██████████| 1262/1262 [16:09<00:00,  1.30it/s, Loss=0.0914, Dice=0.4081]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.67it/s]
# Phase 2 - Epoch 9/30: 100%|██████████| 1262/1262 [16:14<00:00,  1.30it/s, Loss=0.1444, Dice=0.2332]
# Validation: 100%|██████████| 271/271 [01:43<00:00,  2.62it/s]
# Phase 2 - Epoch 10/30: 100%|██████████| 1262/1262 [16:20<00:00,  1.29it/s, Loss=0.0279, Dice=0.4387]
# Validation: 100%|██████████| 271/271 [01:42<00:00,  2.64it/s]
# Phase 2 - Epoch 11/30: 100%|██████████| 1262/1262 [16:17<00:00,  1.29it/s, Loss=0.0509, Dice=0.3284]
# Validation: 100%|██████████| 271/271 [01:43<00:00,  2.63it/s]
# Phase 2 - Epoch 12/30: 100%|██████████| 1262/1262 [16:13<00:00,  1.30it/s, Loss=0.3976, Dice=0.3403]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.68it/s]
# Phase 2 - Epoch 13/30: 100%|██████████| 1262/1262 [16:15<00:00,  1.29it/s, Loss=0.0261, Dice=0.4673]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.68it/s]
# Phase 2 - Epoch 14/30: 100%|██████████| 1262/1262 [16:15<00:00,  1.29it/s, Loss=0.0592, Dice=0.4581]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.66it/s]
# Phase 2 - Epoch 15/30: 100%|██████████| 1262/1262 [16:12<00:00,  1.30it/s, Loss=0.0323, Dice=0.5298]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.67it/s]
# Phase 2 - Epoch 16/30: 100%|██████████| 1262/1262 [17:44<00:00,  1.19it/s, Loss=0.0770, Dice=0.5837]
# Validation: 100%|██████████| 271/271 [02:15<00:00,  2.00it/s]
# Phase 2 - Epoch 17/30: 100%|██████████| 1262/1262 [17:45<00:00,  1.18it/s, Loss=0.0332, Dice=0.3108]
# Validation: 100%|██████████| 271/271 [01:42<00:00,  2.65it/s]
# Phase 2 - Epoch 18/30: 100%|██████████| 1262/1262 [16:15<00:00,  1.29it/s, Loss=0.0302, Dice=0.3580]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.67it/s]
# Phase 2 - Epoch 19/30: 100%|██████████| 1262/1262 [16:12<00:00,  1.30it/s, Loss=0.1707, Dice=0.5845]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.66it/s]
# Phase 2 - Epoch 20/30: 100%|██████████| 1262/1262 [16:11<00:00,  1.30it/s, Loss=0.0245, Dice=0.3635]
# Validation: 100%|██████████| 271/271 [01:42<00:00,  2.66it/s]
# Phase 2 - Epoch 21/30: 100%|██████████| 1262/1262 [16:11<00:00,  1.30it/s, Loss=0.0141, Dice=0.3198]
# Validation: 100%|██████████| 271/271 [01:42<00:00,  2.65it/s]
# Phase 2 - Epoch 22/30: 100%|██████████| 1262/1262 [16:11<00:00,  1.30it/s, Loss=0.0921, Dice=0.1919]
# Validation: 100%|██████████| 271/271 [01:41<00:00,  2.68it/s]
# Phase 2 - Epoch 23/30: 100%|██████████| 1262/1262 [16:05<00:00,  1.31it/s, Loss=0.0193, Dice=0.5135]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.70it/s]
# Phase 2 - Epoch 24/30: 100%|██████████| 1262/1262 [16:03<00:00,  1.31it/s, Loss=0.0325, Dice=0.2984]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.70it/s]
# Phase 2 - Epoch 25/30: 100%|██████████| 1262/1262 [16:04<00:00,  1.31it/s, Loss=0.0230, Dice=0.4390]
# Validation: 100%|██████████| 271/271 [01:38<00:00,  2.76it/s]
# Phase 2 - Epoch 26/30: 100%|██████████| 1262/1262 [15:58<00:00,  1.32it/s, Loss=0.0375, Dice=0.4352]
# Validation: 100%|██████████| 271/271 [01:38<00:00,  2.76it/s]
# Phase 2 - Epoch 27/30: 100%|██████████| 1262/1262 [15:58<00:00,  1.32it/s, Loss=0.0161, Dice=0.7121]
# Validation: 100%|██████████| 271/271 [01:36<00:00,  2.81it/s]
# Phase 2 - Epoch 28/30: 100%|██████████| 1262/1262 [16:01<00:00,  1.31it/s, Loss=0.0226, Dice=0.5877]
# Validation: 100%|██████████| 271/271 [01:40<00:00,  2.69it/s]
# Phase 2 - Epoch 29/30: 100%|██████████| 1262/1262 [15:57<00:00,  1.32it/s, Loss=0.0335, Dice=0.7127]
# Validation: 100%|██████████| 271/271 [01:36<00:00,  2.80it/s]
# Phase 2 - Epoch 30/30: 100%|██████████| 1262/1262 [15:52<00:00,  1.32it/s, Loss=0.0225, Dice=0.4415]
# Validation: 100%|██████████| 271/271 [01:37<00:00,  2.79it/s]
# Testing: 100%|██████████| 271/271 [02:06<00:00,  2.14it/s]
